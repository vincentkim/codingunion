# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('./train.csv')

# %%
type(train)
# Out:
# pandas.core.frame.DataFrame

# %%
train.head()
# Out:
#    time  temp_avg_gap  hum_avg_gap  temp_max_min  temp_min_max  hum_max_min  \
# 0    11          0.08        -0.02           0.2           0.0          0.0
# 1    10          0.08        -0.12           0.2           0.0         -0.1
# 2    10          0.06         0.02           0.1           0.0          0.1
# 3    13          0.08        -0.14           0.1           0.0         -0.1
# 4    13          0.10        -0.14           0.2           0.0          0.0
#
#    hum_min_max  status  work
# 0         -0.1      21     1
# 1         -0.2      21     1
# 2          0.0      21     1
# 3         -0.2      21     1
# 4         -0.2      21     1

# %%
train.shape[0]
# Out:
# 521

# %%
train.isnull().sum()
train.head()
# Out:
#    time  temp_avg_gap  hum_avg_gap  temp_max_min  temp_min_max  hum_max_min  \
# 0    11          0.08        -0.02           0.2           0.0          0.0
# 1    10          0.08        -0.12           0.2           0.0         -0.1
# 2    10          0.06         0.02           0.1           0.0          0.1
# 3    13          0.08        -0.14           0.1           0.0         -0.1
# 4    13          0.10        -0.14           0.2           0.0          0.0
#
#    hum_min_max  status  work
# 0         -0.1      21     1
# 1         -0.2      21     1
# 2          0.0      21     1
# 3         -0.2      21     1
# 4         -0.2      21     1

# %%
#시간 순서 정렬
#train_time = train.sort_values(by=['cur_time'], axis=0)
#train_time

#온도 범위를 사용한 정렬
#train_time[train_time['temp_avg'] >= train_time['temp_avg'].mean()]

# %%
idx1 = train_time[(train_time['temp_max'] > 50) | (train_time['temp_min'] < -20)].index
train_time = train_time.drop(idx1)
idx2 = train_time[(train_time['hum_max'] > 100) | (train_time['hum_min'] < 0)].index
train_time = train_time.drop(idx2)

num = train_time.shape[0]
train_time = train_time.reindex(range(num), method='ffill')
train_time.head(num)
# Out:
#     temp_max  temp_min  temp_avg  hum_max  hum_min  hum_avg  \
# 0       23.7      23.6     23.68     54.4     54.2    54.32
# 1       23.7      23.6     23.62     54.3     54.3    54.30
# 2       23.6      23.6     23.60     54.3     54.3    54.30
# 3       23.6      23.6     23.60     54.3     54.3    54.30
# 4       23.6      23.6     23.60     54.5     54.3    54.40
# 5       23.6      23.6     23.60     54.6     54.5    54.58
# 6       23.6      23.6     23.60     54.6     54.6    54.60
# 7       23.6      23.6     23.60     54.6     54.5    54.56
# 8       23.6      23.5     23.52     54.5     54.4    54.48
# 9       23.5      23.5     23.50     54.5     54.4    54.48
# 10      23.5      23.5     23.50     54.5     54.5    54.50
# 11      23.5      23.5     23.50     54.5     54.5    54.50
# 12      23.5      23.4     23.48     54.5     54.5    54.50
# 13      23.5      23.4     23.44     54.5     54.5    54.50
# 14      23.5      23.4     23.42     54.6     54.5    54.52
# ...

# %%
round(train_time['temp_avg'][0] - train_time['temp_avg'][1], 2)
# Out:
# 0.06

# %%
train_time['temp_avg'][1]
# Out:
# 23.62

# %%
import datetime

# %%
datetime.datetime.strptime(train_time['cur_time'][0], '%Y-%m-%dT%H:%M:%S.%fZ')
# Out:
# datetime.datetime(2020, 9, 9, 18, 36, 54)

# %%
datetime.datetime.strptime(train_time['cur_time'][1], '%Y-%m-%dT%H:%M:%S.%fZ')
# Out:
# datetime.datetime(2020, 9, 9, 18, 37, 4)

# %%
datetime.datetime.strptime(train_time['cur_time'][1], '%Y-%m-%dT%H:%M:%S.%fZ') - datetime.datetime.strptime(train_time['cur_time'][0], '%Y-%m-%dT%H:%M:%S.%fZ')
# Out:
# datetime.timedelta(0, 10)

# %%
#date80_0 = datetime.datetime.strptime(train_time['cur_time'][80], '%Y-%m-%dT%H:%M:%S.%fZ') - datetime.datetime.strptime(train_time['cur_time'][0], '%Y-%m-%dT%H:%M:%S.%fZ')

# %%
#date80_0

# %%
#res = round(date80_0.seconds + date80_0.days * 24 * 3600)

# %%
#print(res)
#print(type(res))

# %%
'''
count = 0
for i in range(train.shape[0]-1):
    count = count + 1
    #i와 I+1 간의 status 가 같은 경우, 시간값을 빼서 구한 경과 시간, temp의 차이를 뺀 값, 평균값의 차 같은 것을 모아놓은 새로운 csv파일을 생성한다
    print(datetime.datetime.strptime(train_time['cur_time'][i+1], '%Y-%m-%dT%H:%M:%S.%fZ') - datetime.datetime.strptime(train_time['cur_time'][i], '%Y-%m-%dT%H:%M:%S.%fZ'))
    print(type(datetime.datetime.strptime(train_time['cur_time'][i+1], '%Y-%m-%dT%H:%M:%S.%fZ') - datetime.datetime.strptime(train_time['cur_time'][i], '%Y-%m-%dT%H:%M:%S.%fZ')))
    print(count)
    
'''
# Out:
# "\ncount = 0\nfor i in range(train.shape[0]-1):\n    count = count + 1\n    #i와 I+1 간의 status 가 같은 경우, 시간값을 빼서 구한 경과 시간, temp의 차이를 뺀 값, 평균값의 차 같은 것을 모아놓은 새로운 csv파일을 생성한다\n    print(datetime.datetime.strptime(train_time['cur_time'][i+1], '%Y-%m-%dT%H:%M:%S.%fZ') - datetime.datetime.strptime(train_time['cur_time'][i], '%Y-%m-%dT%H:%M:%S.%fZ'))\n    print(type(datetime.datetime.strptime(train_time['cur_time'][i+1], '%Y-%m-%dT%H:%M:%S.%fZ') - datetime.datetime.strptime(train_time['cur_time'][i], '%Y-%m-%dT%H:%M:%S.%fZ')))\n    print(count)\n    \n"

# %%
f = open("test4091n.csv", "w")

f.write( 'time' )
f.write(",")
f.write('temp_avg_gap')
f.write(",")
f.write('hum_avg_gap')
f.write(",")
f.write('temp_max_min')
f.write(",")
f.write('temp_min_max')
f.write(",")
f.write('hum_max_min')
f.write(",")
f.write('hum_min_max')
f.write(",")
f.write('status')
f.write(",")
f.write('work')
f.write("\n")

for i in range(train_time.shape[0]-1):
    if train_time['status'][i+1] == train_time['status'][i] and train_time['serial'][i+1] == train_time['serial'][i]:
        data = datetime.datetime.strptime(train_time['cur_time'][i+1], '%Y-%m-%dT%H:%M:%S.%fZ') - datetime.datetime.strptime(train_time['cur_time'][i], '%Y-%m-%dT%H:%M:%S.%fZ')
        res = round(data.seconds + data.days * 24 * 3600)
        f.write( str(res) )
        f.write(",")
        f.write(str(round(train_time['temp_avg'][i+1] - train_time['temp_avg'][i], 2)))
        f.write(",")
        f.write(str(round(train_time['hum_avg'][i+1] - train_time['hum_avg'][i], 2)))
        f.write(",")
        f.write(str(round(train_time['temp_max'][i+1] - train_time['temp_min'][i], 2)))
        f.write(",")
        f.write(str(round(train_time['temp_min'][i+1] - train_time['temp_max'][i], 2)))
        f.write(",")
        f.write(str(round(train_time['hum_max'][i+1] - train_time['hum_min'][i], 2)))
        f.write(",")
        f.write(str(round(train_time['hum_min'][i+1] - train_time['hum_max'][i], 2)))
        f.write(",")
        f.write(str(train_time['status'][i]))
        f.write(",")
        f.write('0')
        f.write("\n")
f.close()

# %%
fortrain = pd.read_csv('./train01.csv')

# %%
fortrain.head(10)
# Out:
#    time  temp_avg_gap  hum_avg_gap  temp_max_min  temp_min_max  hum_max_min  \
# 0    11          0.08        -0.02           0.2           0.0          0.0
# 1    10          0.08        -0.12           0.2           0.0         -0.1
# 2    10          0.06         0.02           0.1           0.0          0.1
# 3    13          0.08        -0.14           0.1           0.0         -0.1
# 4    13          0.10        -0.14           0.2           0.0          0.0
# 5    23          0.12        -0.20           0.3           0.0         -0.1
# 6    10          0.16        -0.26           0.3           0.0         -0.1
# 7    11          0.10        -0.22           0.2           0.0         -0.1
# 8    13          0.10        -0.02           0.1           0.1          0.1
# 9    10          0.04        -0.08           0.1           0.0          0.0
#
#    hum_min_max  status  work
# 0         -0.1      21     1
# 1         -0.2      21     1
# 2          0.0      21     1
# ...

# %%
fortrain.shape
# Out:
# (493, 9)

# %%
from sklearn.linear_model import LogisticRegression
ml = LogisticRegression(solver='lbfgs')

# %%
x = fortrain.drop(["work"], axis=1)
y = fortrain["work"]
ml.fit(x, y)
ml.coef_
# Out:
# array([[-4.11122374e-02,  1.31851709e+00,  1.83017918e-01,
#          2.78861729e+00, -3.14411418e-01,  3.96952030e-01,
#         -3.49436900e-01, -2.43752175e-03]])

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
k_fold = KFold(n_splits=10, shuffle=True, random_state=0)

scoring = 'accuracy'
score = cross_val_score(ml, x, y, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)

round(np.mean(score)*100, 2)
# Out:
# [0.68       0.64       0.66       0.55102041 0.81632653 0.69387755
#  0.67346939 0.65306122 0.57142857 0.53061224]
# 64.7

# %%
test = pd.read_csv('./test02.csv')
predict = ml.predict(test.drop(['work'], axis=1))
result =pd.DataFrame({
    'status': test['status'],
    'work': predict
})
result.to_csv('working02.csv', index=False)
